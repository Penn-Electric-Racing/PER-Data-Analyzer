# %% [markdown]
# # Penn Electric Racing Data Analyzer: PERDA
#
# Welcome to PERDA: PER custom python library for data processing needs.
#
# Instructions:
# - This is a template notebook to demonstrate PERDA.
# - PERDA can be installed locally, or on google colab.
# - Having access to PERDA github repo will give you access to the library
# - Please follow instructions for online OR local installation.

# %%
# Import libraries
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import tqdm
import os

# %% [markdown]
# ## Colab Instructions:

# %% [markdown]
# We use github repo to install the library. Simply run the following code to install perda:

# %%
# Run this cell for perda updates, and potential branch changes
ORG_NAME = "Penn-Electric-Racing"
REPO_NAME = "PER-Data-Analyzer"
BRANCH = "main"  # Branch Input

# !pip uninstall -y perda #Avoid perda overlap incase of updates
# !pip install git+https://github.com/{ORG_NAME}/{REPO_NAME}.git@{BRANCH}

# %% [markdown]
# You can mount PER google drive and access data files if you have access

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
'''path to folder --> Choose your path, personal or PER drive'''

#folder_path = '/content/drive/MyDrive/REV8/TESTING/REV8 Testing Data/'
folder_path = '/content/drive/Shareddrives/FSAE Penn Electric Racing/REV8/TESTING/REV8 Testing Data'

'''If using uploaded file, comment previous and uncomment next'''
#folder_path = 'relative/path/to/your/file'

# %%
#run this cell if you need to see the available directories
os.listdir(folder_path)

# %%
# Name of the log file
logfile = folder_path + "/10_08/01_01_00 12_18_59 AM.csv"
'''
if using personal drive
'''
#logfile = "/04_24/04_24_23 07_41_13 PM.csv"
'''
If using uploaded file, comment previous and uncomment next
'''
#logfile = folder_path

# %% [markdown]
# ## Local Instructions

# %% [markdown]
# PERDA can also be installed locally. You will need to clone the git repo locally.
#
# - Open terminal, `cd` to the folder you want to put repo
# - Run `git clone https://github.com/Penn-Electric-Racing/PER-Data-Analyzer.git`
# - Make sure your python env is activated, then run `pip install .`
# - Set your path for logfile

# %%
# logfile = "path/to/your/csv/file"
logfile = "../Tests/csv files/[Practice Endurance] 05_25_23 09_39_05 PM.csv" #example

# %% [markdown]
# ## Code Demo

# %% [markdown]
# Import perda and create instance. You can create multiple perda instence for reading multiple csv at the same time.

# %%
import perda

aly = perda.create() #creating analyser object
aly2 = perda.create()
aly3 = perda.create()
# Out:
# Analyzer Created
# Analyzer Created
# Analyzer Created

# %% [markdown]
# Perda parse all data base on timestamp of one high frequency data \
# If no input, default to highest frequency data

# %%
aly.read_csv(logfile) # Reading the csv file using raw timestamp
# aly2.read_csv(logfile, input_align_name = "max_freq") # Reading csv aligning with max freq variable (Don't want to do this usually)
# aly3.read_csv(logfile, input_align_name = "sdl.currentTime") # Reading csv with known align variable. Do this if such variable exists and you know which one it is.
# Out:
# Reset Analyzer
# Reading file: PER CSV Modbus Log 05/25/23 09:39:05 PM
# Processing CSV: 17791117lines [00:26, 667086.03lines/s]
# Csv parsing complete.

# %%
# Print all possible input can variables. Good for copying down in text editor and find your stuff :)
aly.print_input_can_variables()
# Out:
# Can Variables                                    Info
# ------------------------------------------------------
# ams.airsState                                    AirsState
# ams.board.glvTemp                                GLV Board Temperature
# ams.board.hvTemp                                 HV Board Temperature
# ams.cellCount                                    Cell Count
# ams.charging.commandI                            Current Command
# ams.charging.commandV                            Voltage Command
# ams.chipCount                                    Chip Count
# ams.connections.chargerCanConnected              Charger Connected over CAN
# ams.connections.dashCanConnected                 Dashboard Connected over CAN
# ams.connections.pcmCanConnected                  Powertrain Control Module Connected over CAN
# ams.connections.pduCanConnected                  Power Distribution Unit Connected over CAN
# ams.connections.sdlCanConnected                  Telemetry Connected over CAN
# ams.error                                        Error
# ams.fanSpeed                                     Fan Speed
# ams.faults.cell0v                                Cell 0V
# ams.faults.celluv                                Cell UV
# ams.faults.comm                                  Comm
# ams.faults.discWhileChg                          Discharge while Charging
# ams.faults.extFault                              External Power Fault
# ams.faults.overChargeCurrent                     Over Charge Current
# ams.faults.overCurrent                           Over Current
# ams.faults.overDieTemp                           Over Die Temperature
# ams.faults.overGlvTemp                           Over GLV Board Temperature
# ams.faults.overHvTemp                            Over HV Board Temperature
# ams.faults.overPackTemp                          Over Temperature
# ams.faults.overPower                             Over Power
# ams.faults.overVoltage                           Over Voltage
# ams.faults.post                                  Post
# ams.faults.precharge                             Precharge
# ams.faults.prechargeAirsClosed                   Precharge AIRs Closed
# ams.faults.prechargeNegAirClosed                 Precharge Negative AIR Closed
# ams.faults.prechargePackVoltage                  Precharge Pack Voltage Check
# ams.faults.ref                                   Ref
# ams.faults.selftest                              Selftest
# ams.faults.sensor                                Sensor
# ams.faults.underCurrent                          Under Current
# ams.faults.underDieTemp                          Under Die Temperature
# ams.faults.underGlvTemp                          Under GLV Board Temperature
# ams.faults.underHvTemp                           Under HV Board Temperature
# ams.faults.underPackTemp                         Under Temperature
# ams.faults.underPower                            Under Power
# ams.faults.underVoltage                          Under Voltage
# ams.faults.vsenseMismatch                        Vsense Mismatch
# ams.imd.resistance                               Resistance
# ams.imd.status                                   Status
# ams.minionsConnected                             Minions Connected
# ams.pack.capacity                                Capacity
# ams.pack.capacityLeft                            Remaining Capacity
# ams.pack.currH                                   Current (High)
# ams.pack.currHraw                                Current Raw Value (High)
# ams.pack.currL                                   Current (Low)
# ams.pack.currLraw                                Current Raw Value (Low)
# ams.pack.current                                 Current
# ams.pack.errors.capacityInit                     Capacity Init
# ams.pack.errors.currentH                         Current H
# ams.pack.errors.currentL                         Current L
# ams.pack.errors.socInit                          Soc Init
# ams.pack.errors.start                            Start
# ams.pack.errors.voltage                          Voltage
# ams.pack.power                                   Power
# ams.pack.soc                                     State of Charge
# ams.pack.voltage                                 Voltage
# ams.resetCause                                   Reset Cause
# ams.signals.airSupply                            AIR Supply
# ams.signals.amsFltLat                            AMS Fault Latch
# ams.signals.amsOk                                AMS OK
# ams.signals.balanceMode                          Balance Mode
# ams.signals.dcDcOn                               DC DC On
# ams.signals.fanOn                                Fan On
# ams.signals.imdFltLat                            IMD Fault Latch
# ams.signals.imdOk                                IMD OK
# ams.signals.negContactor                         Negative Contactor
# ams.signals.posContactor                         Positive Contactor
# ams.signals.prechargeRelay                       Precharge Relay
# ams.signals.startDelay                           Start Delay
# ams.signals.tractiveEnIn                         Tractive Enable Input
# ams.stack.cells.cellV[0]                         Cell Voltage
# ams.stack.cells.cellV[100]                       Cell Voltage
# ams.stack.cells.cellV[101]                       Cell Voltage
# ams.stack.cells.cellV[102]                       Cell Voltage
# ams.stack.cells.cellV[103]                       Cell Voltage
# ams.stack.cells.cellV[104]                       Cell Voltage
# ams.stack.cells.cellV[105]                       Cell Voltage
# ams.stack.cells.cellV[106]                       Cell Voltage
# ams.stack.cells.cellV[107]                       Cell Voltage
# ams.stack.cells.cellV[108]                       Cell Voltage
# ams.stack.cells.cellV[109]                       Cell Voltage
# ams.stack.cells.cellV[10]                        Cell Voltage
# ams.stack.cells.cellV[110]                       Cell Voltage
# ams.stack.cells.cellV[111]                       Cell Voltage
# ams.stack.cells.cellV[11]                        Cell Voltage
# ams.stack.cells.cellV[12]                        Cell Voltage
# ams.stack.cells.cellV[13]                        Cell Voltage
# ams.stack.cells.cellV[14]                        Cell Voltage
# ams.stack.cells.cellV[15]                        Cell Voltage
# ams.stack.cells.cellV[16]                        Cell Voltage
# ams.stack.cells.cellV[17]                        Cell Voltage
# ams.stack.cells.cellV[18]                        Cell Voltage
# ams.stack.cells.cellV[19]                        Cell Voltage
# ams.stack.cells.cellV[1]                         Cell Voltage
# ams.stack.cells.cellV[20]                        Cell Voltage
# ams.stack.cells.cellV[21]                        Cell Voltage
# ams.stack.cells.cellV[22]                        Cell Voltage
# ams.stack.cells.cellV[23]                        Cell Voltage
# ams.stack.cells.cellV[24]                        Cell Voltage
# ams.stack.cells.cellV[25]                        Cell Voltage
# ams.stack.cells.cellV[26]                        Cell Voltage
# ams.stack.cells.cellV[27]                        Cell Voltage
# ams.stack.cells.cellV[28]                        Cell Voltage
# ams.stack.cells.cellV[29]                        Cell Voltage
# ams.stack.cells.cellV[2]                         Cell Voltage
# ams.stack.cells.cellV[30]                        Cell Voltage
# ams.stack.cells.cellV[31]                        Cell Voltage
# ams.stack.cells.cellV[32]                        Cell Voltage
# ams.stack.cells.cellV[33]                        Cell Voltage
# ams.stack.cells.cellV[34]                        Cell Voltage
# ams.stack.cells.cellV[35]                        Cell Voltage
# ams.stack.cells.cellV[36]                        Cell Voltage
# ams.stack.cells.cellV[37]                        Cell Voltage
# ams.stack.cells.cellV[38]                        Cell Voltage
# ams.stack.cells.cellV[39]                        Cell Voltage
# ams.stack.cells.cellV[3]                         Cell Voltage
# ams.stack.cells.cellV[40]                        Cell Voltage
# ams.stack.cells.cellV[41]                        Cell Voltage
# ams.stack.cells.cellV[42]                        Cell Voltage
# ams.stack.cells.cellV[43]                        Cell Voltage
# ams.stack.cells.cellV[44]                        Cell Voltage
# ams.stack.cells.cellV[45]                        Cell Voltage
# ams.stack.cells.cellV[46]                        Cell Voltage
# ams.stack.cells.cellV[47]                        Cell Voltage
# ams.stack.cells.cellV[48]                        Cell Voltage
# ams.stack.cells.cellV[49]                        Cell Voltage
# ams.stack.cells.cellV[4]                         Cell Voltage
# ams.stack.cells.cellV[50]                        Cell Voltage
# ams.stack.cells.cellV[51]                        Cell Voltage
# ams.stack.cells.cellV[52]                        Cell Voltage
# ams.stack.cells.cellV[53]                        Cell Voltage
# ams.stack.cells.cellV[54]                        Cell Voltage
# ams.stack.cells.cellV[55]                        Cell Voltage
# ams.stack.cells.cellV[56]                        Cell Voltage
# ams.stack.cells.cellV[57]                        Cell Voltage
# ams.stack.cells.cellV[58]                        Cell Voltage
# ams.stack.cells.cellV[59]                        Cell Voltage
# ams.stack.cells.cellV[5]                         Cell Voltage
# ams.stack.cells.cellV[60]                        Cell Voltage
# ams.stack.cells.cellV[61]                        Cell Voltage
# ams.stack.cells.cellV[62]                        Cell Voltage
# ams.stack.cells.cellV[63]                        Cell Voltage
# ams.stack.cells.cellV[64]                        Cell Voltage
# ams.stack.cells.cellV[65]                        Cell Voltage
# ams.stack.cells.cellV[66]                        Cell Voltage
# ams.stack.cells.cellV[67]                        Cell Voltage
# ams.stack.cells.cellV[68]                        Cell Voltage
# ams.stack.cells.cellV[69]                        Cell Voltage
# ams.stack.cells.cellV[6]                         Cell Voltage
# ams.stack.cells.cellV[70]                        Cell Voltage
# ams.stack.cells.cellV[71]                        Cell Voltage
# ams.stack.cells.cellV[72]                        Cell Voltage
# ams.stack.cells.cellV[73]                        Cell Voltage
# ams.stack.cells.cellV[74]                        Cell Voltage
# ams.stack.cells.cellV[75]                        Cell Voltage
# ams.stack.cells.cellV[76]                        Cell Voltage
# ams.stack.cells.cellV[77]                        Cell Voltage
# ams.stack.cells.cellV[78]                        Cell Voltage
# ams.stack.cells.cellV[79]                        Cell Voltage
# ams.stack.cells.cellV[7]                         Cell Voltage
# ams.stack.cells.cellV[80]                        Cell Voltage
# ams.stack.cells.cellV[81]                        Cell Voltage
# ams.stack.cells.cellV[82]                        Cell Voltage
# ams.stack.cells.cellV[83]                        Cell Voltage
# ams.stack.cells.cellV[84]                        Cell Voltage
# ams.stack.cells.cellV[85]                        Cell Voltage
# ams.stack.cells.cellV[86]                        Cell Voltage
# ams.stack.cells.cellV[87]                        Cell Voltage
# ams.stack.cells.cellV[88]                        Cell Voltage
# ams.stack.cells.cellV[89]                        Cell Voltage
# ams.stack.cells.cellV[8]                         Cell Voltage
# ams.stack.cells.cellV[90]                        Cell Voltage
# ams.stack.cells.cellV[91]                        Cell Voltage
# ams.stack.cells.cellV[92]                        Cell Voltage
# ams.stack.cells.cellV[93]                        Cell Voltage
# ams.stack.cells.cellV[94]                        Cell Voltage
# ams.stack.cells.cellV[95]                        Cell Voltage
# ams.stack.cells.cellV[96]                        Cell Voltage
# ams.stack.cells.cellV[97]                        Cell Voltage
# ams.stack.cells.cellV[98]                        Cell Voltage
# ams.stack.cells.cellV[99]                        Cell Voltage
# ams.stack.cells.cellV[9]                         Cell Voltage
# ams.stack.mma.Vana.avg                           Average
# ams.stack.mma.Vana.max                           Maximum
# ams.stack.mma.Vana.maxIndex                      Maximum Index
# ams.stack.mma.Vana.min                           Minimum
# ams.stack.mma.Vana.minIndex                      Minimum Index
# ams.stack.mma.Vdd.avg                            Average
# ams.stack.mma.Vdd.max                            Maximum
# ams.stack.mma.Vdd.maxIndex                       Maximum Index
# ams.stack.mma.Vdd.min                            Minimum
# ams.stack.mma.Vdd.minIndex                       Minimum Index
# ams.stack.mma.cellV.avg                          Average
# ams.stack.mma.cellV.max                          Maximum
# ams.stack.mma.cellV.maxIndex                     Maximum Index
# ams.stack.mma.cellV.min                          Minimum
# ams.stack.mma.cellV.minIndex                     Minimum Index
# ams.stack.mma.chipCellSum.avg                    Average
# ams.stack.mma.chipCellSum.max                    Maximum
# ams.stack.mma.chipCellSum.maxIndex               Maximum Index
# ams.stack.mma.chipCellSum.min                    Minimum
# ams.stack.mma.chipCellSum.minIndex               Minimum Index
# ams.stack.mma.dieTemp.avg                        Average
# ams.stack.mma.dieTemp.max                        Maximum
# ams.stack.mma.dieTemp.maxIndex                   Maximum Index
# ams.stack.mma.dieTemp.min                        Minimum
# ams.stack.mma.dieTemp.minIndex                   Minimum Index
# ams.stack.mma.intRef.avg                         Average
# ams.stack.mma.intRef.max                         Maximum
# ams.stack.mma.intRef.maxIndex                    Maximum Index
# ams.stack.mma.intRef.min                         Minimum
# ams.stack.mma.intRef.minIndex                    Minimum Index
# ams.stack.mma.temp.avg                           Average
# ams.stack.mma.temp.max                           Maximum
# ams.stack.mma.temp.maxIndex                      Maximum Index
# ams.stack.mma.temp.min                           Minimum
# ams.stack.mma.temp.minIndex                      Minimum Index
# ams.stack.thermistors.temperature[0]             Temperature
# ams.stack.thermistors.temperature[10]            Temperature
# ams.stack.thermistors.temperature[11]            Temperature
# ams.stack.thermistors.temperature[12]            Temperature
# ams.stack.thermistors.temperature[13]            Temperature
# ams.stack.thermistors.temperature[14]            Temperature
# ams.stack.thermistors.temperature[15]            Temperature
# ams.stack.thermistors.temperature[16]            Temperature
# ams.stack.thermistors.temperature[17]            Temperature
# ams.stack.thermistors.temperature[18]            Temperature
# ams.stack.thermistors.temperature[19]            Temperature
# ams.stack.thermistors.temperature[1]             Temperature
# ams.stack.thermistors.temperature[20]            Temperature
# ams.stack.thermistors.temperature[21]            Temperature
# ams.stack.thermistors.temperature[22]            Temperature
# ams.stack.thermistors.temperature[23]            Temperature
# ams.stack.thermistors.temperature[24]            Temperature
# ams.stack.thermistors.temperature[25]            Temperature
# ams.stack.thermistors.temperature[26]            Temperature
# ams.stack.thermistors.temperature[27]            Temperature
# ams.stack.thermistors.temperature[28]            Temperature
# ams.stack.thermistors.temperature[29]            Temperature
# ams.stack.thermistors.temperature[2]             Temperature
# ams.stack.thermistors.temperature[30]            Temperature
# ams.stack.thermistors.temperature[31]            Temperature
# ams.stack.thermistors.temperature[32]            Temperature
# ams.stack.thermistors.temperature[33]            Temperature
# ams.stack.thermistors.temperature[34]            Temperature
# ams.stack.thermistors.temperature[35]            Temperature
# ams.stack.thermistors.temperature[36]            Temperature
# ams.stack.thermistors.temperature[37]            Temperature
# ams.stack.thermistors.temperature[38]            Temperature
# ams.stack.thermistors.temperature[39]            Temperature
# ams.stack.thermistors.temperature[3]             Temperature
# ams.stack.thermistors.temperature[40]            Temperature
# ams.stack.thermistors.temperature[41]            Temperature
# ams.stack.thermistors.temperature[42]            Temperature
# ams.stack.thermistors.temperature[43]            Temperature
# ams.stack.thermistors.temperature[44]            Temperature
# ams.stack.thermistors.temperature[45]            Temperature
# ams.stack.thermistors.temperature[46]            Temperature
# ams.stack.thermistors.temperature[47]            Temperature
# ams.stack.thermistors.temperature[4]             Temperature
# ams.stack.thermistors.temperature[5]             Temperature
# ams.stack.thermistors.temperature[6]             Temperature
# ams.stack.thermistors.temperature[7]             Temperature
# ams.stack.thermistors.temperature[8]             Temperature
# ams.stack.thermistors.temperature[9]             Temperature
# ams.stack.voltage                                Voltage
# ams.startTime                                    Start Time
# ams.thermistorCount                              thermistor Count
# ams.threads.prechargeTime                        Precharge Thread Loop Time
# ams.threads.sensorTime                           Sensor Thread Loop Time
# ams.threads.slaveTime                            Slave Thread Loop Time
# ams.threads.updateTime                           Update Thread Loop Time
# ams.vSensorMismatch                              Vsensor Mismatch
# ams.watchdog.prechargeTimeout                    Precharge Thread Timeout
# ams.watchdog.sensorTimeout                       Sensor Thread Timeout
# ams.watchdog.slaveTimeout                        Slave Thread Timeout
# ams.watchdog.startupTimeout                      Startup Timeout
# ams.watchdog.updateTimeout                       Update Thread Timeout
# charger.chargerOk                                Charger Ok
# charger.connections.amsCanConnected              Accumulator Management System Connected over CAN
# charger.current                                  Current
# charger.dashCanConnected                         Dashboard Connected over CAN
# charger.faults.battery                           Battery Fault
# charger.faults.estop                             Emergency Stop Pressed
# charger.faults.hardware                          Hardware Fault
# charger.faults.overPower                         Power High
# charger.faults.overheat                          Overheating Fault
# charger.faults.relayOff                          Relay Power
# charger.faults.shutdown                          Shutdown
# charger.faults.timeout                           Communication Timeout
# charger.faults.wrongVolt                         Wrong Volt Fault
# charger.maxCurrent                               Max Current
# charger.maxPower                                 Max Power
# charger.maxVoltage                               Max Voltage
# charger.outletCurrent                            Outlet Current
# charger.outletVoltage                            Outlet Voltage
# charger.resetCause                               Reset Cause
# charger.voltage                                  Voltage
# dash.backLeft.tireTemperature[0]                 Tire Temperatures
# dash.backLeft.tireTemperature[10]                Tire Temperatures
# dash.backLeft.tireTemperature[11]                Tire Temperatures
# dash.backLeft.tireTemperature[12]                Tire Temperatures
# dash.backLeft.tireTemperature[13]                Tire Temperatures
# dash.backLeft.tireTemperature[14]                Tire Temperatures
# dash.backLeft.tireTemperature[15]                Tire Temperatures
# dash.backLeft.tireTemperature[1]                 Tire Temperatures
# dash.backLeft.tireTemperature[2]                 Tire Temperatures
# dash.backLeft.tireTemperature[3]                 Tire Temperatures
# dash.backLeft.tireTemperature[4]                 Tire Temperatures
# dash.backLeft.tireTemperature[5]                 Tire Temperatures
# dash.backLeft.tireTemperature[6]                 Tire Temperatures
# dash.backLeft.tireTemperature[7]                 Tire Temperatures
# dash.backLeft.tireTemperature[8]                 Tire Temperatures
# dash.backLeft.tireTemperature[9]                 Tire Temperatures
# dash.backRight.tireTemperature[0]                Tire Temperatures
# dash.backRight.tireTemperature[10]               Tire Temperatures
# dash.backRight.tireTemperature[11]               Tire Temperatures
# dash.backRight.tireTemperature[12]               Tire Temperatures
# dash.backRight.tireTemperature[13]               Tire Temperatures
# dash.backRight.tireTemperature[14]               Tire Temperatures
# dash.backRight.tireTemperature[15]               Tire Temperatures
# dash.backRight.tireTemperature[1]                Tire Temperatures
# dash.backRight.tireTemperature[2]                Tire Temperatures
# dash.backRight.tireTemperature[3]                Tire Temperatures
# dash.backRight.tireTemperature[4]                Tire Temperatures
# dash.backRight.tireTemperature[5]                Tire Temperatures
# dash.backRight.tireTemperature[6]                Tire Temperatures
# dash.backRight.tireTemperature[7]                Tire Temperatures
# dash.backRight.tireTemperature[8]                Tire Temperatures
# dash.backRight.tireTemperature[9]                Tire Temperatures
# dash.connections.amsCanConnected                 Accumulator Management System Connected over CAN
# dash.connections.pcmCanConnected                 Powertrain Control Module Connected over CAN
# dash.connections.pduCanConnected                 Power Distribution Unit Connected over CAN
# dash.connections.sdlCanConnected                 Telemetry Connected over CAN
# dash.drive.light                                 Light
# dash.drive.pressed                               Pressed
# dash.faults.can                                  CAN
# dash.faults.tireTempCan                          Tire Temperature CAN
# dash.frontLeft.tireTemperature[0]                Tire Temperatures
# dash.frontLeft.tireTemperature[10]               Tire Temperatures
# dash.frontLeft.tireTemperature[11]               Tire Temperatures
# dash.frontLeft.tireTemperature[12]               Tire Temperatures
# dash.frontLeft.tireTemperature[13]               Tire Temperatures
# dash.frontLeft.tireTemperature[14]               Tire Temperatures
# dash.frontLeft.tireTemperature[15]               Tire Temperatures
# dash.frontLeft.tireTemperature[1]                Tire Temperatures
# dash.frontLeft.tireTemperature[2]                Tire Temperatures
# dash.frontLeft.tireTemperature[3]                Tire Temperatures
# dash.frontLeft.tireTemperature[4]                Tire Temperatures
# dash.frontLeft.tireTemperature[5]                Tire Temperatures
# dash.frontLeft.tireTemperature[6]                Tire Temperatures
# dash.frontLeft.tireTemperature[7]                Tire Temperatures
# dash.frontLeft.tireTemperature[8]                Tire Temperatures
# dash.frontLeft.tireTemperature[9]                Tire Temperatures
# dash.frontRight.tireTemperature[0]               Tire Temperatures
# dash.frontRight.tireTemperature[10]              Tire Temperatures
# dash.frontRight.tireTemperature[11]              Tire Temperatures
# dash.frontRight.tireTemperature[12]              Tire Temperatures
# dash.frontRight.tireTemperature[13]              Tire Temperatures
# dash.frontRight.tireTemperature[14]              Tire Temperatures
# dash.frontRight.tireTemperature[15]              Tire Temperatures
# dash.frontRight.tireTemperature[1]               Tire Temperatures
# dash.frontRight.tireTemperature[2]               Tire Temperatures
# dash.frontRight.tireTemperature[3]               Tire Temperatures
# dash.frontRight.tireTemperature[4]               Tire Temperatures
# dash.frontRight.tireTemperature[5]               Tire Temperatures
# dash.frontRight.tireTemperature[6]               Tire Temperatures
# dash.frontRight.tireTemperature[7]               Tire Temperatures
# dash.frontRight.tireTemperature[8]               Tire Temperatures
# dash.frontRight.tireTemperature[9]               Tire Temperatures
# dash.knob.count                                  Encoder Count
# dash.knob.pressed                                Pressed
# dash.log.light                                   Light
# dash.log.pressed                                 Pressed
# dash.mode.light                                  Light
# dash.mode.pressed                                Pressed
# dash.resetCause                                  Reset Cause
# dash.screen                                      Current Screen
# dash.select.light                                Light
# dash.select.pressed                              Pressed
# dash.signals.carReset                            Car Reset
# dash.signals.clearFaults                         Clear Faults
# dash.signals.modeChange                          Mode Change
# dash.signals.nextScreen                          Next Screen
# dash.signals.startRequest                        Start Request
# dash.signals.stopRequest                         Stop Request
# dash.threads.buttonTime                          Button Thread Loop Time
# dash.threads.displayTime                         Display Thread Loop Time
# dash.threads.sensorTime                          Sensor Thread Loop Time
# dash.threads.updateTime                          Update Thread Loop Time
# dash.watchdog.buttonTimeout                      Button Thread Timeout
# dash.watchdog.displayTimeout                     Display Thread Timeout
# dash.watchdog.sensorTimeout                      Sensor Thread Timeout
# dash.watchdog.startupTimeout                     Startup Timeout
# dash.watchdog.updateTimeout                      Update Thread Timeout
# pcm.analogVoltage                                5V Analog Voltage
# pcm.boardTemperature                             Board Temperature
# pcm.connections.amsCanConnected                  Accumulator Management System Connected over CAN
# pcm.connections.dashCanConnected                 Dashboard Connected over CAN
# pcm.connections.pduCanConnected                  Power Distribution Unit Connected over CAN
# pcm.connections.sdlCanConnected                  Telemetry Connected over CAN
# pcm.cooling.frontFlow                            Front Flow Rate
# pcm.cooling.radInletLeft                         Left Radiator Inlet
# pcm.cooling.radInletRight                        Right Radiator Inlet
# pcm.cooling.radOutletLeft                        Left Radiator Outlet
# pcm.cooling.radOutletRight                       Right Radiator Outlet
# pcm.cooling.rearFlow                             Rear Flow Rate
# pcm.cooling.temp                                 Temperature
# pcm.cooling.tempRaw                              Temperature Raw Value
# pcm.distanceTraveled                             Distance Traveled
# pcm.driveMode                                    Drive Modes
# pcm.extVoltage                                   5V Ext Voltage
# pcm.faults.buckConverter                         Buck Converter
# pcm.faults.can                                   CAN
# pcm.faults.coolantNFlow                          Coolant NFlow
# pcm.faults.extAnaSupply                          External Analog Supply
# pcm.faults.fixedSupply                           Fixed Supply
# pcm.faults.mocCan                                MOC CAN
# pcm.faults.mocTimeout                            MOC Timeout
# pcm.frontLoadCell                                Front Load Cell
# pcm.i2c.extAnaFilterConnected                    External Analog Filter Connected
# pcm.i2c.extAnaPullConnected                      External Analog Pull Connected
# pcm.i2c.fixedPullConnected                       Fixed Pull Up/Down Connected
# pcm.moc.controlBoardTemp                         Control Board Temp
# pcm.moc.dcBusCurrent                             DC Bus Current
# pcm.moc.dcBusPower                               DC Bus Power
# pcm.moc.dcBusVoltage                             DC Bus Voltage
# pcm.moc.faults.hasPostFault                      Has Post Fault
# pcm.moc.faults.hasRunFault                       Has Run Fault
# pcm.moc.faults.post12VSenseHigh                  12V Sense Voltage High
# pcm.moc.faults.post12VSenseLow                   12V Sense Voltage Low
# pcm.moc.faults.post1pt5SenseHigh                 1.5V Sense Voltage High
# pcm.moc.faults.post1pt5SenseLow                  1.5V Sense Voltage Low
# pcm.moc.faults.post2pt5SenseHigh                 2.5V Sense Voltage High
# pcm.moc.faults.post2pt5SenseLow                  2.5V Sense Voltage Low
# pcm.moc.faults.post5VSenseHigh                   5V Sense Voltage High
# pcm.moc.faults.post5VSenseLow                    5V Sense Voltage Low
# pcm.moc.faults.postControlPCBTempHigh            Control PCB Temperature High
# pcm.moc.faults.postControlPCBTempLow             Control PCB Temperature Low
# pcm.moc.faults.postCurrentSensorHigh             Current Sensor High
# pcm.moc.faults.postCurrentSensorLow              Current Sensor Low
# pcm.moc.faults.postDCBusHigh                     DC Bus Voltage High
# pcm.moc.faults.postDCBusLow                      DC Bus Voltage Low
# pcm.moc.faults.postDesaturation                  Desaturation Fault
# pcm.moc.faults.postGatePCBTempHigh               Gate Drive PCB Temprature High
# pcm.moc.faults.postGatePCBTempLow                Gate Drive PCB Temperature Low
# pcm.moc.faults.postHwOverCurrent                 HW Over Current Fault
# pcm.moc.faults.postModuleTemperatureHigh         Module Temperature High
# pcm.moc.faults.postModuleTemperatureLow          Module Temperature Low
# pcm.moc.faults.runCanCommandMessage              CAN Command Message Lost
# pcm.moc.faults.runCurrentSensorFault             Current Sensor Fault
# pcm.moc.faults.runDesaturation                   Desaturation Fault
# pcm.moc.faults.runDirectionCommandFault          Direction Command
# pcm.moc.faults.runGateDriveBoard1OverTemp        Gate Drive Board 1 Over Temperature
# pcm.moc.faults.runGateDriveBoard2OverTemp        Gate Drive Board 2 Over Temperature
# pcm.moc.faults.runGateDriveBoard3OverTemp        Gate Drive Board 3 Over Temperature
# pcm.moc.faults.runHardwareDCBusOverVoltage       Hardware DC Bus Over-Voltage
# pcm.moc.faults.runHwOverCurrent                  HW Over Current
# pcm.moc.faults.runInverterOverTemp               Inverter over-temperature
# pcm.moc.faults.runInverterResponseTimeOut        Inverter Response Time-out
# pcm.moc.faults.runModuleAOverTemp                Module A Over-Temperature
# pcm.moc.faults.runModuleBOverTemp                Module B Over-Temperature
# pcm.moc.faults.runModuleCOverTemp                Moodule C Over-Temperature
# pcm.moc.faults.runMotorOverSpeed                 Motor Over-speed
# pcm.moc.faults.runMotorOverTemp                  Motor Over-Temperature
# pcm.moc.faults.runOverCurrent                    Over-current
# pcm.moc.faults.runOverVoltage                    Over-voltage
# pcm.moc.faults.runPCBOverTemp                    PCB Over Temperature
# pcm.moc.faults.runResolverNotConnected           Resolver Not Connected
# pcm.moc.faults.runUnderVoltage                   Under Voltage
# pcm.moc.fiveRef                                  5V Ref
# pcm.moc.fluxCommand                              Flux Command
# pcm.moc.fluxFeedback                             Flux Feedback
# pcm.moc.fluxWeakeningOutput                      Flux Weakening Output
# pcm.moc.gateDriverBoardTemp                      Gate Driver Board Temp
# pcm.moc.hotSpotTemp                              Hot Spot Temp
# pcm.moc.idCommand                                Id Command
# pcm.moc.idFeedback                               Id Feedback
# pcm.moc.iqCommand                                Iq Command
# pcm.moc.iqFeedback                               Iq Feedback
# pcm.moc.modulationIndex                          Modulation Index
# pcm.moc.motor.angle                              Angle
# pcm.moc.motor.angularSpeed                       Angular Speed
# pcm.moc.motor.inverterReady                      Inverter Ready
# pcm.moc.motor.inverterStatus                     Inverter Status
# pcm.moc.motor.postFault                          Post Fault Status
# pcm.moc.motor.requestedTorque                    Torque Requested
# pcm.moc.motor.runFault                           Run Fault Status
# pcm.moc.motor.temp                               Temperature
# pcm.moc.motor.timestamp                          Timestamp
# pcm.moc.motor.torqueCommand                      Torque Command
# pcm.moc.motor.torqueFeedback                     Torque Feedback
# pcm.moc.motor.wheelSpeed                         Linear Speed
# pcm.moc.onePointFiveRef                          1.5V Ref
# pcm.moc.outputVoltage                            Output Voltage
# pcm.moc.phaseACurrent                            Phase A Current
# pcm.moc.phaseATemp                               Phase A Temp
# pcm.moc.phaseBCurrent                            Phase B Current
# pcm.moc.phaseBTemp                               Phase B Temp
# pcm.moc.phaseCCurrent                            Phase C Current
# pcm.moc.phaseCTemp                               Phase C Temp
# pcm.moc.temp                                     Temperature
# pcm.moc.timestamp                                Timestamp
# pcm.moc.twelveRef                                12V Ref
# pcm.moc.twoPointFiveRef                          2.5V Ref
# pcm.moc.vdVoltage                                VD Voltage
# pcm.moc.vqVoltage                                VQ Voltage
# pcm.mode                                         Mode
# pcm.nav.accel.x                                  X Acceleration
# pcm.nav.accel.y                                  Y Acceleration
# pcm.nav.accel.z                                  Z Acceleration
# pcm.nav.accelRaw.x                               X Acceleration
# pcm.nav.accelRaw.y                               Y Acceleration
# pcm.nav.accelRaw.z                               Z Acceleration
# pcm.nav.frontGps.fix                             Fix
# pcm.nav.frontGps.numSats                         Number of Satellites
# pcm.nav.gyro.x                                   X Angular Velocity
# pcm.nav.gyro.y                                   Y Angular Velocity
# pcm.nav.gyro.z                                   Z Angular Velocity
# pcm.nav.gyroRaw.x                                X Angular Velocity
# pcm.nav.gyroRaw.y                                Y Angular Velocity
# pcm.nav.gyroRaw.z                                Z Angular Velocity
# pcm.nav.ins.acceleration.x                       X Acceleration
# pcm.nav.ins.acceleration.y                       Y Acceleration
# pcm.nav.ins.acceleration.z                       Z Acceleration
# pcm.nav.ins.orientation.pitch                    Pitch
# pcm.nav.ins.orientation.roll                     Roll
# pcm.nav.ins.orientation.yaw                      Yaw
# pcm.nav.ins.position.altitude                    Altitude
# pcm.nav.ins.position.latitude                    Latitute
# pcm.nav.ins.position.longitude                   Longitude
# pcm.nav.ins.status.gpsError                      GPS Error
# pcm.nav.ins.status.gpsHeadingIns                 GPS Heading INS
# pcm.nav.ins.status.gpsfix                        GPS Fix
# pcm.nav.ins.status.imuError                      IMU Error
# pcm.nav.ins.status.magPresError                  Magnetometer/Pressure Error
# pcm.nav.ins.status.mode                          Mode
# pcm.nav.ins.uncertainty.position                 Position Uncertainty
# pcm.nav.ins.uncertainty.velocity                 Velocity Uncertainty
# pcm.nav.ins.uncertainty.ypr.pitch                Pitch Uncertainty
# pcm.nav.ins.uncertainty.ypr.roll                 Roll Uncertainty
# pcm.nav.ins.uncertainty.ypr.yaw                  Yaw Uncertainty
# pcm.nav.ins.velocity.x                           X Velocity
# pcm.nav.ins.velocity.y                           Y Velocity
# pcm.nav.ins.velocity.z                           Z Velocity
# pcm.nav.mag.x                                    X Magnetic Field
# pcm.nav.mag.y                                    Y Magnetic Field
# pcm.nav.mag.z                                    Z Magnetic Field
# pcm.nav.millis                                   Miliseconds
# pcm.nav.pressure                                 Pressure
# pcm.nav.rearGps.fix                              Fix
# pcm.nav.rearGps.numSats                          Number of Satellites
# pcm.nav.rotation.pitch                           Pitch
# pcm.nav.rotation.roll                            Roll
# pcm.nav.rotation.yaw                             Yaw
# pcm.nav.temperature                              Temperature
# pcm.nav.time                                     Time
# pcm.param.accelExponent                          Accel Exponent
# pcm.param.accelLimit                             Accel Limit
# pcm.param.backWheelSpeedGearTeethPerRev          Back Wheel Speed Sensor Gear Teeth Per Rev
# pcm.param.driveTest                              Drive Test
# pcm.param.fanTemperature                         Fan Temperature
# pcm.param.frontWheelSpeedGearTeethPerRev         Front Wheel Speed Sensor Gear Teeth Per Rev
# pcm.param.gearRatio                              Gear Ratio
# pcm.param.gpsAOffset.x                           X
# pcm.param.gpsAOffset.y                           Y
# pcm.param.gpsAOffset.z                           Z
# pcm.param.gpsBaseline.x                          X
# pcm.param.gpsBaseline.y                          Y
# pcm.param.gpsBaseline.z                          Z
# pcm.param.gpsBaselineUncertainty.x               X
# pcm.param.gpsBaselineUncertainty.y               Y
# pcm.param.gpsBaselineUncertainty.z               Z
# pcm.param.hobble.currentLimit                    Hobble Current Limit
# pcm.param.hobble.mocTempThreshold                Hobble MOC Temp Threshold
# pcm.param.hobble.motorTempThreshold              Hobble Motor Temp Threshold
# pcm.param.hobble.packTempThreshold               Hobble Pack Temp Threshold
# pcm.param.hobble.socThreshold                    Hobble State of Charge Threshold
# pcm.param.inverterEnable                         Inverter Enable
# pcm.param.launchControl.maxTorqueSpeed           Launch Control Max Torque Speed
# pcm.param.launchControl.startTorque              Launch Control Start Torque
# pcm.param.limp.accelLimit                        Limp Acceleration Limit
# pcm.param.limp.mocTempThreshold                  Limp MOC Temp Threshold
# pcm.param.limp.motorTempThreshold                Limp Motor Temp Threshold
# pcm.param.limp.packTempThreshold                 Limp Pack Temp Threshold
# pcm.param.limp.socThreshold                      Limp State of Charge Threshold
# pcm.param.motor.kt                               Motor Torque Constant
# pcm.param.motor.kv                               Motor Velocity Constant
# pcm.param.overrideSpeed                          Override Speed
# pcm.param.pedals.limits.accelLeft.absHigh        Absolute High
# pcm.param.pedals.limits.accelLeft.absLow         Absolute Low
# pcm.param.pedals.limits.accelLeft.rangeHigh      Range High
# pcm.param.pedals.limits.accelLeft.rangeLow       Range Low
# pcm.param.pedals.limits.accelRight.absHigh       Absolute High
# pcm.param.pedals.limits.accelRight.absLow        Absolute Low
# pcm.param.pedals.limits.accelRight.rangeHigh     Range High
# pcm.param.pedals.limits.accelRight.rangeLow      Range Low
# pcm.param.pedals.limits.brakeForce.absHigh       Absolute High
# pcm.param.pedals.limits.brakeForce.absLow        Absolute Low
# pcm.param.pedals.limits.brakeForce.rangeHigh     Range High
# pcm.param.pedals.limits.brakeForce.rangeLow      Range Low
# pcm.param.pedals.limits.brakePressure.absHigh    Absolute High
# pcm.param.pedals.limits.brakePressure.absLow     Absolute Low
# pcm.param.pedals.limits.brakePressure.rangeHigh  Range High
# pcm.param.pedals.limits.brakePressure.rangeLow   Range Low
# pcm.param.pedals.testBspd                        Test BSPD
# pcm.param.pedals.thresholds.accelActuated        Accel Actuated
# pcm.param.pedals.thresholds.accelReleased        Accel Released
# pcm.param.pedals.thresholds.brakeActuated        Brake Actuated
# pcm.param.pedals.thresholds.brakeLaunch          Brake Launch
# pcm.param.pedals.thresholds.brakeLight           Brake Light
# pcm.param.pedals.thresholds.brakeStart           Brake Start
# pcm.param.pedals.thresholds.impAllowance         Implausibility allowance
# pcm.param.pedals.thresholds.mismatchAllowance    Mismatch Allowance
# pcm.param.pullRodOffset                          Pull Rod Offset
# pcm.param.pullRodSlope                           Pull Rod Slope
# pcm.param.pushRodOffset                          Push Rod Offset
# pcm.param.pushRodSlope                           Push Rod Slope
# pcm.param.regen.accelThreshold                   Regen Accel Threshold
# pcm.param.regen.maxBrakePressure                 Regen Max Brake Pressure Actuation
# pcm.param.regen.maxCellTemp                      Regen Max Cell Temp
# pcm.param.regen.maxCellVoltage                   Regen Max Cell Voltage
# pcm.param.regen.minBrakePressure                 Regen Min Brake Pressure Actuation
# pcm.param.regen.minSpeed                         Regen Min Speed
# pcm.param.rtdsStartBeeps                         Ready To Drive Sound Start Beeps
# pcm.param.speedLimit                             Vel Limit
# pcm.param.speedOverride                          Speed Override
# pcm.param.steerRangeHigh                         Steering Angle Range High
# pcm.param.steerRangeLow                          Steering Angle Range Low
# pcm.param.torqueLimit                            Torque Limit
# pcm.param.wheelDiameter                          Wheel Diameter
# pcm.param.wheelPulses                            Wheel Pulses
# pcm.param.wheelSpeedTimeConstant                 Wheel Speed Time Constant
# pcm.pedals.accel                                 Accel
# pcm.pedals.brakeForce                            Brake Force
# pcm.pedals.brakeForceRaw                         Brake Force Raw
# pcm.pedals.frontBrakePressure                    Front Brake Pressure
# pcm.pedals.implausibility.accelLeftLlim          Accel Left Lower Limit
# pcm.pedals.implausibility.accelLeftUlim          Accel Left Upper Limit
# pcm.pedals.implausibility.accelMismatch          Accel Mismatch
# pcm.pedals.implausibility.accelRightLlim         Accel Right Lower Limit
# pcm.pedals.implausibility.accelRightUlim         Accel Right Upper Limit
# pcm.pedals.implausibility.anyImplausibility      Any Implausibility
# pcm.pedals.implausibility.brakeAndAccel          Brake And Accel
# pcm.pedals.implausibility.brakeForceLlim         Brake Force Lower Limit
# pcm.pedals.implausibility.brakeForceUlim         Brake Force Upper Limit
# pcm.pedals.implausibility.brakePressureFLlim     Front Brake Pressure Lower Limit
# pcm.pedals.implausibility.brakePressureFUlim     Front Brake Pressure Upper Limit
# pcm.pedals.implausibility.brakePressureMismatch  Brake Pressure Mismatch
# pcm.pedals.implausibility.brakePressureRLlim     Rear Brake Pressure Lower Limit
# pcm.pedals.implausibility.brakePressureRUlim     Rear Brake Pressure Upper Limit
# pcm.pedals.rearBrakePressure                     Rear Brake Pressure
# pcm.rearLoadCell                                 Rear Load Cell
# pcm.regenTorque                                  Regen torque
# pcm.resetCause                                   Reset Cause
# pcm.shouldRegen                                  Regen enabled
# pcm.signals.brakeLight                           Brake Light
# pcm.signals.bspdOk                               Bspd OK
# pcm.signals.hobbleMode                           Hobble Mode
# pcm.signals.limpMode                             Limp Mode
# pcm.signals.mocReady                             Moc Ready
# pcm.signals.pcmOk                                Pcm OK
# pcm.signals.rtdsBeeping                          Rtds Beeping
# pcm.signals.startRequest                         Start Request
# pcm.signals.stopRequest                          Stop Request
# pcm.startTime                                    Start Time
# pcm.steerAngle                                   SteerAngle
# pcm.steerAngleRaw                                SteerAngle Analog In
# pcm.strain.pullRod                               Pull Rod Strain Gauge
# pcm.strain.pullRodRaw                            Pull Rod Strain Gauge Raw
# pcm.strain.pushRod                               Push Rod Strain Gauge
# pcm.strain.pushRodRaw                            Push Rod Strain Gauge Raw
# pcm.supplyVoltage                                Supply Voltage
# pcm.threads.controllerReadTime                   Controller Read Thread Loop Time
# pcm.threads.controllerTime                       Controller Thread Loop Time
# pcm.threads.sensorTime                           Sensor Thread Loop Time
# pcm.threads.updateTime                           Update Thread Loop Time
# pcm.watchdog.controllerTimeout                   Controller Thread Timeout
# pcm.watchdog.sensorTimeout                       Sensor Thread Timeout
# pcm.watchdog.startupTimeout                      Startup Timeout
# pcm.watchdog.updateTimeout                       Update Thread Timeout
# pcm.wheelSpeeds.backLeft                         Back Left Wheel Speed
# pcm.wheelSpeeds.backRight                        Back Right Wheel Speed
# pcm.wheelSpeeds.frontLeft                        Front Left Wheel Speed
# pcm.wheelSpeeds.frontRight                       Front Right Wheel Speed
# pdu.connections.amsCanConnected                  Accumulator Manangement System Connected over CAN
# pdu.connections.dashCanConnected                 Dashboard Connected over CAN
# pdu.connections.pcmCanConnected                  Powertrain Control Module Connected over CAN
# pdu.connections.sdlCanConnected                  Telemetry Connected over CAN
# pdu.faults.buckConverter                         Buck Converter
# pdu.faults.oc                                    Overcurrent
# pdu.faults.ocBat                                 Battery overcurrent
# pdu.faults.ocBat                                 Battery overcurrent
# pdu.faults.ocChannel[0]                          Channel Overcurrent
# pdu.faults.ocChannel[10]                         Channel Overcurrent
# pdu.faults.ocChannel[11]                         Channel Overcurrent
# pdu.faults.ocChannel[12]                         Channel Overcurrent
# pdu.faults.ocChannel[13]                         Channel Overcurrent
# pdu.faults.ocChannel[14]                         Channel Overcurrent
# pdu.faults.ocChannel[15]                         Channel Overcurrent
# pdu.faults.ocChannel[16]                         Channel Overcurrent
# pdu.faults.ocChannel[17]                         Channel Overcurrent
# pdu.faults.ocChannel[18]                         Channel Overcurrent
# pdu.faults.ocChannel[19]                         Channel Overcurrent
# pdu.faults.ocChannel[1]                          Channel Overcurrent
# pdu.faults.ocChannel[20]                         Channel Overcurrent
# pdu.faults.ocChannel[21]                         Channel Overcurrent
# pdu.faults.ocChannel[22]                         Channel Overcurrent
# pdu.faults.ocChannel[23]                         Channel Overcurrent
# pdu.faults.ocChannel[2]                          Channel Overcurrent
# pdu.faults.ocChannel[3]                          Channel Overcurrent
# pdu.faults.ocChannel[4]                          Channel Overcurrent
# pdu.faults.ocChannel[5]                          Channel Overcurrent
# pdu.faults.ocChannel[6]                          Channel Overcurrent
# pdu.faults.ocChannel[7]                          Channel Overcurrent
# pdu.faults.ocChannel[8]                          Channel Overcurrent
# pdu.faults.ocChannel[9]                          Channel Overcurrent
# pdu.faults.ocDCDC                                DCDC overcurrent
# pdu.faults.ocDCDC                                DCDC overcurrent
# pdu.faults.ocPCM                                 PCM Overcurrent
# pdu.faults.otBat                                 Battery overtemperature
# pdu.faults.ovCell                                Cell overvoltage
# pdu.faults.uc                                    Undercurrent
# pdu.faults.ucBat                                 Battery undercurrent
# pdu.faults.ucChannel[0]                          Channel Undercurrent
# pdu.faults.ucChannel[10]                         Channel Undercurrent
# pdu.faults.ucChannel[11]                         Channel Undercurrent
# pdu.faults.ucChannel[12]                         Channel Undercurrent
# pdu.faults.ucChannel[13]                         Channel Undercurrent
# pdu.faults.ucChannel[14]                         Channel Undercurrent
# pdu.faults.ucChannel[15]                         Channel Undercurrent
# pdu.faults.ucChannel[16]                         Channel Undercurrent
# pdu.faults.ucChannel[17]                         Channel Undercurrent
# pdu.faults.ucChannel[18]                         Channel Undercurrent
# pdu.faults.ucChannel[19]                         Channel Undercurrent
# pdu.faults.ucChannel[1]                          Channel Undercurrent
# pdu.faults.ucChannel[20]                         Channel Undercurrent
# pdu.faults.ucChannel[21]                         Channel Undercurrent
# pdu.faults.ucChannel[22]                         Channel Undercurrent
# pdu.faults.ucChannel[23]                         Channel Undercurrent
# pdu.faults.ucChannel[2]                          Channel Undercurrent
# pdu.faults.ucChannel[3]                          Channel Undercurrent
# pdu.faults.ucChannel[4]                          Channel Undercurrent
# pdu.faults.ucChannel[5]                          Channel Undercurrent
# pdu.faults.ucChannel[6]                          Channel Undercurrent
# pdu.faults.ucChannel[7]                          Channel Undercurrent
# pdu.faults.ucChannel[8]                          Channel Undercurrent
# pdu.faults.ucChannel[9]                          Channel Undercurrent
# pdu.faults.ucDCDC                                DCDC undercurrent
# pdu.faults.ucPCM                                 PCM Undercurrent
# pdu.faults.utBat                                 Battery undertemperature
# pdu.faults.uvCell                                Cell undervoltage
# pdu.resetCause                                   Reset Cause
# pdu.sensors.batV                                 Battery voltage
# pdu.sensors.boardTemp                            Board temperature
# pdu.sensors.cellV[0]                             Cell voltage
# pdu.sensors.cellV[1]                             Cell voltage
# pdu.sensors.cellV[2]                             Cell voltage
# pdu.sensors.cellV[3]                             Cell voltage
# pdu.sensors.currentBAT                           Battery current
# pdu.sensors.currentBUS                           Bus current
# pdu.sensors.currentDCDC12V                       DC/DC 12V current
# pdu.sensors.currentPCM                           PCM current
# pdu.sensors.currentSHDN                          SHDN current
# pdu.sensors.current[0]                           Current
# pdu.sensors.current[10]                          Current
# pdu.sensors.current[11]                          Current
# pdu.sensors.current[12]                          Current
# pdu.sensors.current[13]                          Current
# pdu.sensors.current[14]                          Current
# pdu.sensors.current[15]                          Current
# pdu.sensors.current[16]                          Current
# pdu.sensors.current[17]                          Current
# pdu.sensors.current[18]                          Current
# pdu.sensors.current[19]                          Current
# pdu.sensors.current[1]                           Current
# pdu.sensors.current[20]                          Current
# pdu.sensors.current[21]                          Current
# pdu.sensors.current[22]                          Current
# pdu.sensors.current[23]                          Current
# pdu.sensors.current[2]                           Current
# pdu.sensors.current[3]                           Current
# pdu.sensors.current[4]                           Current
# pdu.sensors.current[5]                           Current
# pdu.sensors.current[6]                           Current
# pdu.sensors.current[7]                           Current
# pdu.sensors.current[8]                           Current
# pdu.sensors.current[9]                           Current
# pdu.sensors.pg                                   Power good
# pdu.sensors.pwrSense                             3.3V voltage
# pdu.sensors.tempFault                            Temperature fault
# pdu.signals.chargingBat                          Charging from DCDC
# pdu.signals.fans                                 Fans On
# pdu.signals.pduOk                                Pdu ok
# pdu.signals.powerState                           Power State
# pdu.signals.pumps                                Pumps On
# pdu.startTime                                    Start Time
# pdu.threads.controllerTime                       Controller Thread Loop Time
# pdu.threads.parameterTime                        Parameter Thread Loop Time
# pdu.threads.sensorTime                           Sensor Thread Loop Time
# pdu.threads.updateTime                           Update Thread Loop Time
# pdu.watchdog.controllerTimeout                   Controller Thread Timeout
# pdu.watchdog.parameterTimeout                    Parameter Thread Timeout
# pdu.watchdog.sensorTimeout                       Sensor Thread Timeout
# pdu.watchdog.startupTimeout                      Startup Timeout
# pdu.watchdog.updateTimeout                       Update Thread Timeout
# sdl.connections.amsCanConnected                  Accumulator Management System Connected over CAN
# sdl.connections.dashCanConnected                 Dashboard Connected over CAN
# sdl.connections.pcmCanConnected                  Powertrain Control Module Connected over CAN
# sdl.connections.pduCanConnected                  Power Distribution Unit Connected over CAN
# sdl.currentTime                                  Current Time
# sdl.error                                        Error
# sdl.faults.isFull                                SD Full
# sdl.faults.noMount                               SD Mount Fail
# sdl.faults.noSd                                  No SD Card
# sdl.faults.openFail                              SD Open Fail
# sdl.resetCause                                   Reset Cause
# sdl.sd.free_blocks                               Free blocks
# sdl.sd.total_blocks                              Total blocks
# sdl.sd.utilization                               Utilization
# sdl.startTime                                    Start Time
# sdl.threads.logTime                              Log Thread Loop Time
# sdl.threads.receiveTime                          Receive Loop Time
# sdl.threads.updateTime                           Update Thread Loop Time
# sdl.watchdog.logTimeout                          Log Thread Timeout
# sdl.watchdog.receiveTimeout                      Receive Thread Timeout
# sdl.watchdog.startupTimeout                      Startup Timeout
# sdl.watchdog.updateTimeout                       Update Thread Timeout

# %%
# Data summary with given variable name
variables = ["pcm.wheelSpeeds.frontRight"
]

aly.analyze_data(variables)
# aly.analyze_data(variables, start_time=500, end_time=600, time_unit="s")
# aly.analyze_data(variables, start_time=0, end_time=1, time_unit="s")
# Out:
# Statistics for **pcm.wheelSpeeds.frontRight**
# Can ID: 8393
# Data amount: 21862
# Start: 0.000s | End: 2,186.174s | Duration: 2,186.174s
# Max Value: 49.28375 (544.990s)
# Min Value: 0.0 (0.000s)
# Average: 22.407688079376957
# Integral: 48987.10507924384

# %% [markdown]
# Graph variables \
# Always shows HV changes:\
# Red: HV turn on \
# Green: HV turn off

# %%
# Variables to graph
variables = [
    "pcm.moc.motor.requestedTorque",
    "pcm.moc.motor.wheelSpeed",
    "ams.pack.power",
    "ams.pack.voltage"
]
plt.axhline(y=0)
aly.plot(variables)

plt.axhline(y=0)
aly.plot(variables,  start_time = 1000, end_time = 1100, time_unit = "s")

# %% [markdown]
# Dual graph: Plot two different variables, and scale them differently for better visulization\
# Variables comes in pair

# %%
# Dual graph with different scale. Two variables per pair
variables = [
    "pcm.moc.motor.requestedTorque",
    "pcm.moc.motor.wheelSpeed",
    "ams.pack.power",
    "ams.pack.voltage"
]
aly.plot_dual(variables,  start_time = 1000, end_time = 1100, time_unit = "s")
# Out:
# graph for pcm.moc.motor.requestedTorque and pcm.moc.motor.wheelSpeed
# graph for ams.pack.power and ams.pack.voltage

# %% [markdown]
# Align input arrays, fill missing data with three different methods:\
# connect\
# extend_forward\
# extend_backward

# %%
# Align variables for timestamp match

v_al = [
    "ams.pack.voltage",
    "ams.pack.current"
]

# match_type choices: connect, extend_forward, extend_backward
alist = aly.align_array(v_al, match_type="connect")
# alist[0] is aligned voltage; alist[1] is aligned current

# Helper to multiply two nparray for later plotting

product_second_col = alist[0][:, 1] * alist[1][:, 1] /1000 # Multiply every data to get power and correct unit
combined_array = np.column_stack((
    alist[0][:, 0],       # First column (shared)
    product_second_col,  # New second column (product)
    alist[0][:, 2],       # Third column (shared)
    alist[0][:, 3]        # Fourth column (shared)
))

# Compare to power sensor
variables = [
    "ams.pack.power",
    combined_array,
    ]
aly.plot(variables, start_time = 601, end_time = 608, time_unit = "s")

# %% [markdown]
# Built-in array calculation method

# %%
# Internel operation graph function
# Set the variable and the operations between them
v_op = [
    "ams.pack.voltage",
    "*",
    "ams.pack.current"
]

power = aly.get_compute_arrays(v_op, match_type="connect")

variables = [power]
aly.plot(variables, start_time = 1000, end_time = 1100, time_unit = "s")

variables = ["ams.pack.power"]
# Change time_unit to ms
aly.plot(variables, start_time = 1000000, end_time = 1100000, time_unit = "ms")

# %% [markdown]
# FFT for data smoothing (Advanced)

# %%
variables = [
    "pcm.wheelSpeeds.frontLeft",
    "pcm.wheelSpeeds.frontRight"
]

aly.plot(variables, start_time = 500, end_time = 520)

fft_arr = aly.get_band_filter(variables, sample_frequency=5, filtered_lower_band=1)
aly.plot(fft_arr, start_time = 500, end_time = 520)
